# %% [markdown]
# # 동영상파일 → YOLO 좌표추출 & 보간작업

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics

# %%
import os


# [경로 설정]
drive_root = '/content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred'#{Hundred(자세파일)} - output 도 이 파일에 생성
# 1. 원본 영상이 있는 폴더 (경로를 확인해주세요!)
video_folder_path = os.path.join(drive_root,'hundred_video') #동영상들어있는파일 경로
# 2. 정규화된 CSV를 저장할 폴더
norm_folder_path = os.path.join(drive_root, 'keypoint_Hundred','norm_x')  # 저장할 폴더
os.makedirs(norm_folder_path, exist_ok=True)
video_exts = ('.mp4', '.avi', '.mov', '.mkv') # 처리할 영상 확장자

# %%
from ultralytics import YOLO
import cv2
import pandas as pd
import numpy as np  # 정규화 계산을 위해 numpy 추가
import os
import glob # 파일 목록 비교를 위해 glob 추가
import time
from google.colab import drive

# 1. 드라이브 마운트 (최초 1회 실행)
try:
    drive.mount('/content/drive')
except:
    pass # 이미 마운트됨

# --- 2. 정규화 & 보간 함수 (Normalize & Interpolate) ---
# [최신 버전] 보간법이 포함된 정규화 함수입니다.
def normalize_keypoints_named(df):
    """
    [업그레이드 버전]
    1. 몸통 길이 기준으로 정규화 (Normalize)
    2. conf 낮은 값을 보간 (Interpolate)
    """
    df_norm = df.copy()

    # --- 1. 정규화 (Normalize) ---
    l_sh_x, l_sh_y = 'Left_Shoulder_x', 'Left_Shoulder_y'
    r_sh_x, r_sh_y = 'Right_Shoulder_x', 'Right_Shoulder_y'
    l_hip_x, l_hip_y = 'Left_Hip_x', 'Left_Hip_y'
    r_hip_x, r_hip_y = 'Right_Hip_x', 'Right_Hip_y'

    if l_sh_x not in df.columns or l_hip_x not in df.columns:
        print("   ⚠️ 정규화 필수 컬럼(어깨, 골반)이 없어 원본을 저장합니다.")
        return df

    neck_x = (df[l_sh_x] + df[r_sh_x]) / 2
    neck_y = (df[l_sh_y] + df[r_sh_y]) / 2
    pelvis_x = (df[l_hip_x] + df[r_hip_x]) / 2
    pelvis_y = (df[l_hip_y] + df[r_hip_y]) / 2

    torso_length = np.sqrt((neck_x - pelvis_x)**2 + (neck_y - pelvis_y)**2)
    torso_length = torso_length.replace(0, np.nan).fillna(1)

    body_parts = [
        'Nose', 'Left_Eye', 'Right_Eye', 'Left_Ear', 'Right_Ear',
        'Left_Shoulder', 'Right_Shoulder',
        'Left_Elbow', 'Right_Elbow', 'Left_Wrist', 'Right_Wrist',
        'Left_Hip', 'Right_Hip', 'Left_Knee', 'Right_Knee',
        'Left_Ankle', 'Right_Ankle'
    ]

    for part in body_parts:
        col_x = f'{part}_x'
        col_y = f'{part}_y'

        if col_x in df.columns and col_y in df.columns:
            df_norm[f'norm_{part}_x'] = (df[col_x] - pelvis_x) / torso_length
            df_norm[f'norm_{part}_y'] = (df[col_y] - pelvis_y) / torso_length

    # --- 2. 보간 (Interpolate) ---
    for part in body_parts:
        conf_col = f'{part}_conf'
        norm_x_col = f'norm_{part}_x'
        norm_y_col = f'norm_{part}_y'

        if conf_col in df_norm.columns and norm_x_col in df_norm.columns:
            low_conf_mask = df_norm[conf_col] < 0.5 # 0.5 미만 기준
            df_norm.loc[low_conf_mask, norm_x_col] = np.nan
            df_norm.loc[low_conf_mask, norm_y_col] = np.nan

    norm_cols = [col for col in df_norm.columns if col.startswith('norm_')]
    df_norm[norm_cols] = df_norm[norm_cols].interpolate(method='linear', limit_direction='both', limit=5)

    return df_norm

# --- 3. 메인 실행부 (YOLO + 정규화) ---

# --- [핵심 수정] 처리할 파일 목록 비교 ---
print("파일 목록 비교 중...")
all_videos = glob.glob(os.path.join(video_folder_path, "*")) # 모든 파일/폴더
all_video_files = [f for f in all_videos if f.lower().endswith(video_exts)] # 영상 파일만

# 2. 이미 'norm' 폴더에 있는 CSV 파일 목록 (이름만)
existing_norms = glob.glob(os.path.join(norm_folder_path, "norm_*.csv"))
# (예: 'norm_video1.csv' -> 'video1')
existing_norm_names = {os.path.basename(f).replace('norm_', '').replace('.csv', '') for f in existing_norms}

# 3. (비교) 처리해야 할 영상 목록 생성
videos_to_process = []
for video_path in all_video_files:
    # (예: '.../videos/video1.mp4' -> 'video1')
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    if video_name not in existing_norm_names:
        videos_to_process.append(video_path)

if not videos_to_process:
    print("🎉 모든 영상이 이미 정규화되었습니다. 새로 처리할 파일이 없습니다.")
    exit() # 프로그램 종료
else:
    print(f"총 {len(all_video_files)}개 영상 중 {len(videos_to_process)}개를 새로 처리합니다...")
# --- [비교 끝] ---

# 모델 로드
print("⏳ YOLO 모델을 로드 중입니다...")
model = YOLO('yolo11x-pose.pt') # (모델 경로 확인)
print("✅ 모델 로드 완료!")

# 컬럼 이름 미리 정의 (COCO Keypoints 17개)
keypoint_names = [
    "Nose", "Left_Eye", "Right_Eye", "Left_Ear", "Right_Ear",
    "Left_Shoulder", "Right_Shoulder", "Left_Elbow", "Right_Elbow",
    "Left_Wrist", "Right_Wrist", "Left_Hip", "Right_Hip",
    "Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"
]

# [수정] videos_to_process 목록만 순회
total_files = len(videos_to_process)
for i, video_path in enumerate(videos_to_process):
    filename = os.path.basename(video_path)
    csv_filename = os.path.splitext(filename)[0] + '.csv'
    save_path = os.path.join(norm_folder_path, f"norm_{csv_filename}")

    print(f"\n[{i+1}/{total_files}] 분석 중... {filename}")
    start_time = time.time()

    cap = cv2.VideoCapture(video_path)

    # (영상 안 볼거면 show_video = False로 변경)
    show_video = False
    if show_video:
        # ... (이전과 동일한 cv2.namedWindow 코드) ...
        pass

    video_data = [] # 영상 1개의 모든 프레임 데이터를 담을 리스트
    frame_idx = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret: break

        results = model(frame, verbose=False, conf=0.3) # (신뢰도 0.3으로 낮춰서 더 많이 잡게 설정)

        if results[0].keypoints is not None and len(results[0].keypoints) > 0:
            person_kpts = results[0].keypoints.data[0].cpu().numpy()
            frame_data = {"Frame": frame_idx}

            for k, kp in enumerate(person_kpts):
                x, y, conf = kp
                name = keypoint_names[k]
                frame_data[f"{name}_x"] = round(float(x), 2)
                frame_data[f"{name}_y"] = round(float(y), 2)
                frame_data[f"{name}_conf"] = round(float(conf), 2)

            video_data.append(frame_data)

        # ... (show_video 관련 코드) ...

        frame_idx += 1
        if frame_idx % 100 == 0: print(".", end="", flush=True)

    cap.release()
    if show_video: cv2.destroyAllWindows()

    # --- [핵심 수정] 저장 직전에 정규화+보간 적용 ---
    if video_data:
        df_raw = pd.DataFrame(video_data)

        print(" ...정규화 및 보간 적용 중...")
        # [업그레이드된 함수 호출]
        df_normalized_interpolated = normalize_keypoints_named(df_raw)

        df_normalized_interpolated.to_csv(save_path, index=False)

        elapsed = time.time() - start_time
        print(f"\n   ✅ 정규화 완료 및 저장! ({elapsed:.1f}초) -> {save_path}")
    else:
        print(f"\n   ⚠️ 데이터 없음 -> {filename}")

print("\n🎉 모든 신규 작업 끝!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 파일 목록 비교 중...
# 총 117개 영상 중 117개를 새로 처리합니다...
# ⏳ YOLO 모델을 로드 중입니다...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x-pose.pt to 'yolo11x-pose.pt': 100% ━━━━━━━━━━━━ 113.0MB 51.8MB/s 2.2s
# ✅ 모델 로드 완료!
#
# [1/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.14.40_CAM_1.mp4
# ...... ...정규화 및 보간 적용 중...
#
#    ✅ 정규화 완료 및 저장! (45.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.14.40_CAM_1.csv
#
# [2/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.15.35_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.15.35_CAM_1.mp4
#
# [3/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.17.02_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.17.02_CAM_1.mp4
#
# [4/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP076_20220929_15.26.04_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP076_20220929_15.26.04_CAM_1.mp4
#
# [5/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.10.42_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.10.42_CAM_1.mp4
#
# [6/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.11.30_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.11.30_CAM_1.mp4
#
# [7/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.12.19_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.12.19_CAM_1.mp4
#
# [8/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.01.17_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.01.17_CAM_1.mp4
#
# [9/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.02.15_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.02.15_CAM_1.mp4
#
# [10/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.03.10_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.03.10_CAM_1.mp4
#
# [11/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.50.10_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.50.10_CAM_1.mp4
#
# [12/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.01_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.01_CAM_1.mp4
#
# [13/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.54_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.54_CAM_1.mp4
#
# [14/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.52.49_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.52.49_CAM_1.mp4
#
# [15/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.53.42_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.53.42_CAM_1.mp4
#
# [16/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.35.27_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.35.27_CAM_1.mp4
#
# [17/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.36.16_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.36.16_CAM_1.mp4
#
# [18/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.05_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.05_CAM_1.mp4
#
# [19/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.52_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.52_CAM_1.mp4
#
# [20/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.38.46_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.38.46_CAM_1.mp4
#
# [21/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.39.39_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.39.39_CAM_1.mp4
#
# [22/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP092_20221005_11.17.31_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP092_20221005_11.17.31_CAM_1.mp4
#
# [23/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.30.00_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.30.00_CAM_1.mp4
#
# [24/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.30.46_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.30.46_CAM_1.mp4
#
# [25/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.31.33_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.31.33_CAM_1.mp4
#
# [26/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.40.24_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.40.24_CAM_1.mp4
#
# [27/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.41.26_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.41.26_CAM_1.mp4
#
# [28/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.42.27_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.42.27_CAM_1.mp4
#
# [29/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.43.26_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.43.26_CAM_1.mp4
#
# [30/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.44.29_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.44.29_CAM_1.mp4
#
# [31/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.45.20_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.45.20_CAM_1.mp4
#
# [32/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.46.08_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.46.08_CAM_1.mp4
#
# [33/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.15.49_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.15.49_CAM_1.mp4
#
# [34/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.16.51_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.16.51_CAM_1.mp4
#
# [35/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.18.00_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.18.00_CAM_1.mp4
#
# [36/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.19.05_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.19.05_CAM_1.mp4
#
# [37/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.19.49_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.19.49_CAM_1.mp4
#
# [38/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.20.45_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.20.45_CAM_1.mp4
#
# [39/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.21.38_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.21.38_CAM_1.mp4
#
# [40/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.07.30_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.07.30_CAM_1.mp4
#
# [41/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.08.20_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.08.20_CAM_1.mp4
#
# [42/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.09.19_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.09.19_CAM_1.mp4
#
# [43/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.10.25_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.10.25_CAM_1.mp4
#
# [44/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.11.17_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.11.17_CAM_1.mp4
#
# [45/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.12.07_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.12.07_CAM_1.mp4
#
# [46/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.12.55_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.12.55_CAM_1.mp4
#
# [47/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.13.47_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.13.47_CAM_1.mp4
#
# [48/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.07_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.07_CAM_1.mp4
#
# [49/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.53_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.53_CAM_1.mp4
#
# [50/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.37.42_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.37.42_CAM_1.mp4
#
# [51/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.38.28_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.38.28_CAM_1.mp4
#
# [52/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.39.18_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.39.18_CAM_1.mp4
#
# [53/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40.12_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40.12_CAM_1.mp4
#
# [54/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40.59_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40.59_CAM_1.mp4
#
# [55/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.41.49_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.41.49_CAM_1.mp4
#
# [56/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.42.35_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.42.35_CAM_1.mp4
#
# [57/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.43.23_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.43.23_CAM_1.mp4
#
# [58/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.36.09_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.36.09_CAM_1.mp4
#
# [59/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.37.03_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.37.03_CAM_1.mp4
#
# [60/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.37.57_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.37.57_CAM_1.mp4
#
# [61/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.38.54_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.38.54_CAM_1.mp4
#
# [62/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.39.44_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.39.44_CAM_1.mp4
#
# [63/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.40.59_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.40.59_CAM_1.mp4
#
# [64/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.42.02_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.42.02_CAM_1.mp4
#
# [65/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.42.56_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.42.56_CAM_1.mp4
#
# [66/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.43.45_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.43.45_CAM_1.mp4
#
# [67/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.16.59_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.16.59_CAM_1.mp4
#
# [68/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.17.46_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.17.46_CAM_1.mp4
#
# [69/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.18.37_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.18.37_CAM_1.mp4
#
# [70/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.19.24_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.19.24_CAM_1.mp4
#
# [71/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.20.17_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.20.17_CAM_1.mp4
#
# [72/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.22.53_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.22.53_CAM_1.mp4
#
# [73/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.26.00_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.26.00_CAM_1.mp4
#
# [74/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.07.14_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.07.14_CAM_1.mp4
#
# [75/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.08.04_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.08.04_CAM_1.mp4
#
# [76/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.08.53_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.08.53_CAM_1.mp4
#
# [77/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.09.55_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.09.55_CAM_1.mp4
#
# [78/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.10.45_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.10.45_CAM_1.mp4
#
# [79/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.11.37_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.11.37_CAM_1.mp4
#
# [80/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.12.29_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.12.29_CAM_1.mp4
#
# [81/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.13.19_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.13.19_CAM_1.mp4
#
# [82/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.13.16_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.13.16_CAM_1.mp4
#
# [83/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.14.22_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.14.22_CAM_1.mp4
#
# [84/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.15.20_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.15.20_CAM_1.mp4
#
# [85/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.16.13_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.16.13_CAM_1.mp4
#
# [86/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.17.17_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.17.17_CAM_1.mp4
#
# [87/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.18.38_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.18.38_CAM_1.mp4
#
# [88/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.19.28_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.19.28_CAM_1.mp4
#
# [89/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.01.06_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.01.06_CAM_1.mp4
#
# [90/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.01.55_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.01.55_CAM_1.mp4
#
# [91/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.02.45_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.02.45_CAM_1.mp4
#
# [92/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.03.39_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.03.39_CAM_1.mp4
#
# [93/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.04.44_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.04.44_CAM_1.mp4
#
# [94/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.20.51_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.20.51_CAM_1.mp4
#
# [95/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.21.48_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.21.48_CAM_1.mp4
#
# [96/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.22.43_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.22.43_CAM_1.mp4
#
# [97/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.23.38_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.23.38_CAM_1.mp4
#
# [98/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.24.32_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.24.32_CAM_1.mp4
#
# [99/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.25.26_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.25.26_CAM_1.mp4
#
# [100/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.26.20_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.26.20_CAM_1.mp4
#
# [101/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.27.16_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.27.16_CAM_1.mp4
#
# [102/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.52.51_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.52.51_CAM_1.mp4
#
# [103/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.54.00_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.54.00_CAM_1.mp4
#
# [104/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.54.55_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.54.55_CAM_1.mp4
#
# [105/117] 분석 중... 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.55.52_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.55.52_CAM_1.mp4
#
# [106/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.15.09_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.15.09_CAM_1.mp4
#
# [107/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.16.15_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.16.15_CAM_1.mp4
#
# [108/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.17.09_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.17.09_CAM_1.mp4
#
# [109/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.18.05_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.18.05_CAM_1.mp4
#
# [110/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_15.11.39_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_15.11.39_CAM_1.mp4
#
# [111/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.04.49_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.04.49_CAM_1.mp4
#
# [112/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.05.59_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.05.59_CAM_1.mp4
#
# [113/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.07.10_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.07.10_CAM_1.mp4
#
# [114/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.08.25_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.08.25_CAM_1.mp4
#
# [115/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.10.55_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.10.55_CAM_1.mp4
#
# [116/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.12.05_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.12.05_CAM_1.mp4
#
# [117/117] 분석 중... 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.13.11_CAM_1.mp4
#
#    ⚠️ 데이터 없음 -> 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.13.11_CAM_1.mp4
#
# 🎉 모든 신규 작업 끝!

# %%
# --- 3. 메인 실행부 (YOLO + 정규화) ---

print("파일 목록 비교 중...")
all_videos = glob.glob(os.path.join(video_folder_path, "*"))
all_video_files = [f for f in all_videos if f.lower().endswith(video_exts)]

existing_norms = glob.glob(os.path.join(norm_folder_path, "norm_*.csv"))
existing_norm_names = {os.path.basename(f).replace('norm_', '').replace('.csv', '') for f in existing_norms}

videos_to_process = []
for video_path in all_video_files:
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    if video_name not in existing_norm_names:
        videos_to_process.append(video_path)

if not videos_to_process:
    print("🎉 모든 영상이 이미 정규화되었습니다.")
else:
    print(f"총 {len(all_video_files)}개 영상 중 {len(videos_to_process)}개를 새로 처리합니다...")

# 모델 로드
print("⏳ YOLO 모델을 로드 중입니다...")
model = YOLO('yolo11x-pose.pt')
print("✅ 모델 로드 완료!")

keypoint_names = [
    "Nose", "Left_Eye", "Right_Eye", "Left_Ear", "Right_Ear",
    "Left_Shoulder", "Right_Shoulder", "Left_Elbow", "Right_Elbow",
    "Left_Wrist", "Right_Wrist", "Left_Hip", "Right_Hip",
    "Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"
]

total_files = len(videos_to_process)
for i, video_path in enumerate(videos_to_process):
    filename = os.path.basename(video_path)
    csv_filename = os.path.splitext(filename)[0] + '.csv'
    save_path = os.path.join(norm_folder_path, f"norm_{csv_filename}")

    print(f"\n[{i+1}/{total_files}] 분석 시작: {filename}")

    cap = cv2.VideoCapture(video_path)

    # --- [디버깅 1] 영상 파일 열기 실패 확인 ---
    if not cap.isOpened():
        print(f"  ❌ [치명적 오류] 영상을 열 수 없습니다. 경로를 확인하세요.")
        print(f"  -> 경로: {video_path}")
        continue # 다음 영상으로 넘어감

    # --- [디버깅 2] 총 프레임 수 확인 ---
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if total_frames == 0:
        print(f"  ❌ [오류] 영상의 프레임 수가 0입니다. 손상된 파일일 수 있습니다.")
        cap.release()
        continue

    print(f"  ℹ️ 총 프레임 수: {total_frames}")

    start_time = time.time()
    video_data = []
    frame_idx = 0
    detected_frames = 0 # 사람이 감지된 프레임 수 카운트

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            # --- [디버깅 3] 중간에 끊김 확인 ---
            if frame_idx == 0:
                print(f"  ❌ [오류] 첫 번째 프레임을 읽지 못했습니다. (코덱 문제 가능성)")
            break

        # [수정] conf를 0.25로 조금 더 낮춰서 테스트
        results = model(frame, verbose=False, conf=0.25)

        if results[0].keypoints is not None and len(results[0].keypoints.data) > 0:
            # 사람이 감지됨
            person_kpts = results[0].keypoints.data[0].cpu().numpy()

            # [디버깅 4] 키포인트가 너무 적게 잡히는지 확인 (예: 점이 5개 미만이면 무시 등)
            valid_points = np.sum(person_kpts[:, 2] > 0.2) # 신뢰도 0.2 넘는 점 개수

            if valid_points > 5: # 유효한 점이 5개 이상일 때만 저장
                frame_data = {"Frame": frame_idx}
                for k, kp in enumerate(person_kpts):
                    x, y, conf = kp
                    name = keypoint_names[k]
                    frame_data[f"{name}_x"] = round(float(x), 2)
                    frame_data[f"{name}_y"] = round(float(y), 2)
                    frame_data[f"{name}_conf"] = round(float(conf), 2)

                video_data.append(frame_data)
                detected_frames += 1
            else:
                # 감지는 됐지만 점이 너무 적음 (먼 배경 사람 등)
                pass

        frame_idx += 1
        if frame_idx % 50 == 0: print(".", end="", flush=True)

    cap.release()

    # --- 저장 및 결과 보고 ---
    if video_data:
        df_raw = pd.DataFrame(video_data)
        print(f"\n  -> {detected_frames}/{total_frames} 프레임에서 사람 감지됨.")
        print("  ...정규화 및 보간 적용 중...")

        df_normalized_interpolated = normalize_keypoints_named(df_raw)
        df_normalized_interpolated.to_csv(save_path, index=False)

        elapsed = time.time() - start_time
        print(f"  ✅ 저장 완료! ({elapsed:.1f}초) -> {save_path}")
    else:
        print(f"\n  ⚠️ 데이터 없음 -> {filename}")
        # [원인 분석 메시지 출력]
        if detected_frames == 0:
            print(f"     이유: YOLO가 사람을 전혀 찾지 못했습니다. (conf를 낮추거나 영상을 확인하세요)")
        elif total_frames > 0 and frame_idx == 0:
            print(f"     이유: 영상을 열었으나 프레임을 하나도 읽지 못했습니다. (OpenCV/코덱 문제)")

print("\n🎉 작업 종료!")
# Out:
# 파일 목록 비교 중...
# 총 117개 영상 중 116개를 새로 처리합니다...
# ⏳ YOLO 모델을 로드 중입니다...
# ✅ 모델 로드 완료!
#
# [1/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.15.35_CAM_1.mp4
#   ℹ️ 총 프레임 수: 573
# ...........
#   -> 573/573 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.15.35_CAM_1.csv
#
# [2/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.17.02_CAM_1.mp4
#   ℹ️ 총 프레임 수: 580
# ...........
#   -> 580/580 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP075_20220930_11.17.02_CAM_1.csv
#
# [3/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP076_20220929_15.26.04_CAM_1.mp4
#   ℹ️ 총 프레임 수: 606
# ............
#   -> 606/606 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP076_20220929_15.26.04_CAM_1.csv
#
# [4/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.10.42_CAM_1.mp4
#   ℹ️ 총 프레임 수: 504
# ..........
#   -> 504/504 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (34.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.10.42_CAM_1.csv
#
# [5/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.11.30_CAM_1.mp4
#   ℹ️ 총 프레임 수: 557
# ...........
#   -> 557/557 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.11.30_CAM_1.csv
#
# [6/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.12.19_CAM_1.mp4
#   ℹ️ 총 프레임 수: 542
# ..........
#   -> 542/542 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (38.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP077_20220929_11.12.19_CAM_1.csv
#
# [7/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.01.17_CAM_1.mp4
#   ℹ️ 총 프레임 수: 649
# ............
#   -> 649/649 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (44.7초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.01.17_CAM_1.csv
#
# [8/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.02.15_CAM_1.mp4
#   ℹ️ 총 프레임 수: 613
# ............
#   -> 613/613 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.02.15_CAM_1.csv
#
# [9/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.03.10_CAM_1.mp4
#   ℹ️ 총 프레임 수: 626
# ............
#   -> 626/626 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP079_20220928_12.03.10_CAM_1.csv
#
# [10/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.50.10_CAM_1.mp4
#   ℹ️ 총 프레임 수: 623
# ............
#   -> 623/623 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.50.10_CAM_1.csv
#
# [11/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.01_CAM_1.mp4
#   ℹ️ 총 프레임 수: 649
# ............
#   -> 649/649 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (45.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.01_CAM_1.csv
#
# [12/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.54_CAM_1.mp4
#   ℹ️ 총 프레임 수: 684
# .............
#   -> 684/684 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (47.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.51.54_CAM_1.csv
#
# [13/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.52.49_CAM_1.mp4
#   ℹ️ 총 프레임 수: 626
# ............
#   -> 626/626 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.52.49_CAM_1.csv
#
# [14/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.53.42_CAM_1.mp4
#   ℹ️ 총 프레임 수: 659
# .............
#   -> 659/659 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (45.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221006_15.53.42_CAM_1.csv
#
# [15/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.35.27_CAM_1.mp4
#   ℹ️ 총 프레임 수: 554
# ...........
#   -> 554/554 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (38.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.35.27_CAM_1.csv
#
# [16/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.36.16_CAM_1.mp4
#   ℹ️ 총 프레임 수: 554
# ...........
#   -> 554/554 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (37.7초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.36.16_CAM_1.csv
#
# [17/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.05_CAM_1.mp4
#   ℹ️ 총 프레임 수: 517
# ..........
#   -> 517/517 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (36.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.05_CAM_1.csv
#
# [18/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.52_CAM_1.mp4
#   ℹ️ 총 프레임 수: 598
# ...........
#   -> 598/598 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.37.52_CAM_1.csv
#
# [19/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.38.46_CAM_1.mp4
#   ℹ️ 총 프레임 수: 603
# ............
#   -> 603/603 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.38.46_CAM_1.csv
#
# [20/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.39.39_CAM_1.mp4
#   ℹ️ 총 프레임 수: 585
# ...........
#   -> 585/585 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP091_20221011_11.39.39_CAM_1.csv
#
# [21/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP092_20221005_11.17.31_CAM_1.mp4
#   ℹ️ 총 프레임 수: 570
# ...........
#   -> 570/570 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP092_20221005_11.17.31_CAM_1.csv
#
# [22/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.30.00_CAM_1.mp4
#   ℹ️ 총 프레임 수: 512
# ..........
#   -> 512/512 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (36.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.30.00_CAM_1.csv
#
# [23/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.30.46_CAM_1.mp4
#   ℹ️ 총 프레임 수: 478
# .........
#   -> 478/478 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (33.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.30.46_CAM_1.csv
#
# [24/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.31.33_CAM_1.mp4
#   ℹ️ 총 프레임 수: 505
# ..........
#   -> 505/505 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (35.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP098_20221007_11.31.33_CAM_1.csv
#
# [25/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.40.24_CAM_1.mp4
#   ℹ️ 총 프레임 수: 607
# ............
#   -> 607/607 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.40.24_CAM_1.csv
#
# [26/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.41.26_CAM_1.mp4
#   ℹ️ 총 프레임 수: 563
# ...........
#   -> 563/563 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.41.26_CAM_1.csv
#
# [27/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.42.27_CAM_1.mp4
#   ℹ️ 총 프레임 수: 570
# ...........
#   -> 570/570 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.42.27_CAM_1.csv
#
# [28/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.43.26_CAM_1.mp4
#   ℹ️ 총 프레임 수: 620
# ............
#   -> 620/620 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.43.26_CAM_1.csv
#
# [29/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.44.29_CAM_1.mp4
#   ℹ️ 총 프레임 수: 604
# ............
#   -> 604/604 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.44.29_CAM_1.csv
#
# [30/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.45.20_CAM_1.mp4
#   ℹ️ 총 프레임 수: 582
# ...........
#   -> 582/582 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.45.20_CAM_1.csv
#
# [31/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.46.08_CAM_1.mp4
#   ℹ️ 총 프레임 수: 581
# ...........
#   -> 581/581 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP063_20221014_15.46.08_CAM_1.csv
#
# [32/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.15.49_CAM_1.mp4
#   ℹ️ 총 프레임 수: 568
# ...........
#   -> 568/568 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.15.49_CAM_1.csv
#
# [33/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.16.51_CAM_1.mp4
#   ℹ️ 총 프레임 수: 588
# ...........
#   -> 588/588 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.16.51_CAM_1.csv
#
# [34/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.18.00_CAM_1.mp4
#   ℹ️ 총 프레임 수: 536
# ..........
#   -> 536/536 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (37.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.18.00_CAM_1.csv
#
# [35/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.19.05_CAM_1.mp4
#   ℹ️ 총 프레임 수: 517
# ..........
#   -> 517/517 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (35.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.19.05_CAM_1.csv
#
# [36/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.19.49_CAM_1.mp4
#   ℹ️ 총 프레임 수: 619
# ............
#   -> 619/619 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.19.49_CAM_1.csv
#
# [37/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.20.45_CAM_1.mp4
#   ℹ️ 총 프레임 수: 624
# ............
#   -> 624/624 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (44.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.20.45_CAM_1.csv
#
# [38/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.21.38_CAM_1.mp4
#   ℹ️ 총 프레임 수: 684
# .............
#   -> 684/684 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (46.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP064_20221020_15.21.38_CAM_1.csv
#
# [39/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.07.30_CAM_1.mp4
#   ℹ️ 총 프레임 수: 564
# ...........
#   -> 564/564 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (38.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.07.30_CAM_1.csv
#
# [40/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.08.20_CAM_1.mp4
#   ℹ️ 총 프레임 수: 679
# .............
#   -> 679/679 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (47.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.08.20_CAM_1.csv
#
# [41/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.09.19_CAM_1.mp4
#   ℹ️ 총 프레임 수: 570
# ...........
#   -> 570/570 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.09.19_CAM_1.csv
#
# [42/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.10.25_CAM_1.mp4
#   ℹ️ 총 프레임 수: 600
# ............
#   -> 600/600 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.10.25_CAM_1.csv
#
# [43/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.11.17_CAM_1.mp4
#   ℹ️ 총 프레임 수: 581
# ...........
#   -> 581/581 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.11.17_CAM_1.csv
#
# [44/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.12.07_CAM_1.mp4
#   ℹ️ 총 프레임 수: 560
# ...........
#   -> 560/560 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (38.7초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.12.07_CAM_1.csv
#
# [45/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.12.55_CAM_1.mp4
#   ℹ️ 총 프레임 수: 596
# ...........
#   -> 596/596 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.12.55_CAM_1.csv
#
# [46/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.13.47_CAM_1.mp4
#   ℹ️ 총 프레임 수: 632
# ............
#   -> 632/632 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP067_20221012_11.13.47_CAM_1.csv
#
# [47/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.07_CAM_1.mp4
#   ℹ️ 총 프레임 수: 548
# ..........
#   -> 548/548 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.07_CAM_1.csv
#
# [48/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.53_CAM_1.mp4
#   ℹ️ 총 프레임 수: 586
# ...........
#   -> 586/586 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.36.53_CAM_1.csv
#
# [49/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.37.42_CAM_1.mp4
#   ℹ️ 총 프레임 수: 559
# ...........
#   -> 559/559 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.37.42_CAM_1.csv
#
# [50/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.38.28_CAM_1.mp4
#   ℹ️ 총 프레임 수: 568
# ...........
#   -> 568/568 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.7초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.38.28_CAM_1.csv
#
# [51/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.39.18_CAM_1.mp4
#   ℹ️ 총 프레임 수: 606
# ............
#   -> 606/606 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.39.18_CAM_1.csv
#
# [52/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40.12_CAM_1.mp4
#   ℹ️ 총 프레임 수: 580
# ...........
#   -> 580/580 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40.12_CAM_1.csv
#
# [53/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40.59_CAM_1.mp4
#   ℹ️ 총 프레임 수: 554
# ...........
#   -> 554/554 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.40.59_CAM_1.csv
#
# [54/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.41.49_CAM_1.mp4
#   ℹ️ 총 프레임 수: 548
# ..........
#   -> 548/548 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (37.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.41.49_CAM_1.csv
#
# [55/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.42.35_CAM_1.mp4
#   ℹ️ 총 프레임 수: 584
# ...........
#   -> 584/584 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.42.35_CAM_1.csv
#
# [56/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.43.23_CAM_1.mp4
#   ℹ️ 총 프레임 수: 604
# ............
#   -> 604/604 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP069_20221017_11.43.23_CAM_1.csv
#
# [57/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.36.09_CAM_1.mp4
#   ℹ️ 총 프레임 수: 620
# ............
#   -> 620/620 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.36.09_CAM_1.csv
#
# [58/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.37.03_CAM_1.mp4
#   ℹ️ 총 프레임 수: 614
# ............
#   -> 614/614 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.37.03_CAM_1.csv
#
# [59/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.37.57_CAM_1.mp4
#   ℹ️ 총 프레임 수: 626
# ............
#   -> 626/626 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.7초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.37.57_CAM_1.csv
#
# [60/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.38.54_CAM_1.mp4
#   ℹ️ 총 프레임 수: 576
# ...........
#   -> 576/576 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.38.54_CAM_1.csv
#
# [61/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.39.44_CAM_1.mp4
#   ℹ️ 총 프레임 수: 606
# ............
#   -> 606/606 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.39.44_CAM_1.csv
#
# [62/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.40.59_CAM_1.mp4
#   ℹ️ 총 프레임 수: 620
# ............
#   -> 620/620 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.40.59_CAM_1.csv
#
# [63/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.42.02_CAM_1.mp4
#   ℹ️ 총 프레임 수: 564
# ...........
#   -> 564/564 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.42.02_CAM_1.csv
#
# [64/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.42.56_CAM_1.mp4
#   ℹ️ 총 프레임 수: 566
# ...........
#   -> 566/566 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.42.56_CAM_1.csv
#
# [65/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.43.45_CAM_1.mp4
#   ℹ️ 총 프레임 수: 596
# ...........
#   -> 596/596 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP086_20221012_15.43.45_CAM_1.csv
#
# [66/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.16.59_CAM_1.mp4
#   ℹ️ 총 프레임 수: 552
# ...........
#   -> 552/552 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (37.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.16.59_CAM_1.csv
#
# [67/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.17.46_CAM_1.mp4
#   ℹ️ 총 프레임 수: 595
# ...........
#   -> 595/595 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.7초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.17.46_CAM_1.csv
#
# [68/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.18.37_CAM_1.mp4
#   ℹ️ 총 프레임 수: 555
# ...........
#   -> 555/555 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.18.37_CAM_1.csv
#
# [69/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.19.24_CAM_1.mp4
#   ℹ️ 총 프레임 수: 531
# ..........
#   -> 531/531 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (36.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.19.24_CAM_1.csv
#
# [70/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.20.17_CAM_1.mp4
#   ℹ️ 총 프레임 수: 578
# ...........
#   -> 578/578 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.20.17_CAM_1.csv
#
# [71/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.22.53_CAM_1.mp4
#   ℹ️ 총 프레임 수: 548
# ..........
#   -> 548/548 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (38.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.22.53_CAM_1.csv
#
# [72/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.26.00_CAM_1.mp4
#   ℹ️ 총 프레임 수: 546
# ..........
#   -> 546/546 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (38.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221014_11.26.00_CAM_1.csv
#
# [73/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.07.14_CAM_1.mp4
#   ℹ️ 총 프레임 수: 597
# ...........
#   -> 597/597 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.07.14_CAM_1.csv
#
# [74/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.08.04_CAM_1.mp4
#   ℹ️ 총 프레임 수: 546
# ..........
#   -> 546/546 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.08.04_CAM_1.csv
#
# [75/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.08.53_CAM_1.mp4
#   ℹ️ 총 프레임 수: 576
# ...........
#   -> 576/576 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.08.53_CAM_1.csv
#
# [76/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.09.55_CAM_1.mp4
#   ℹ️ 총 프레임 수: 594
# ...........
#   -> 594/594 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.09.55_CAM_1.csv
#
# [77/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.10.45_CAM_1.mp4
#   ℹ️ 총 프레임 수: 604
# ............
#   -> 604/604 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.10.45_CAM_1.csv
#
# [78/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.11.37_CAM_1.mp4
#   ℹ️ 총 프레임 수: 624
# ............
#   -> 624/624 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.11.37_CAM_1.csv
#
# [79/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.12.29_CAM_1.mp4
#   ℹ️ 총 프레임 수: 586
# ...........
#   -> 586/586 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.12.29_CAM_1.csv
#
# [80/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.13.19_CAM_1.mp4
#   ℹ️ 총 프레임 수: 616
# ............
#   -> 616/616 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP096_20221020_11.13.19_CAM_1.csv
#
# [81/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.13.16_CAM_1.mp4
#   ℹ️ 총 프레임 수: 589
# ...........
#   -> 589/589 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.7초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.13.16_CAM_1.csv
#
# [82/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.14.22_CAM_1.mp4
#   ℹ️ 총 프레임 수: 616
# ............
#   -> 616/616 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.14.22_CAM_1.csv
#
# [83/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.15.20_CAM_1.mp4
#   ℹ️ 총 프레임 수: 585
# ...........
#   -> 585/585 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.15.20_CAM_1.csv
#
# [84/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.16.13_CAM_1.mp4
#   ℹ️ 총 프레임 수: 578
# ...........
#   -> 578/578 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (40.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.16.13_CAM_1.csv
#
# [85/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.17.17_CAM_1.mp4
#   ℹ️ 총 프레임 수: 609
# ............
#   -> 609/609 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.17.17_CAM_1.csv
#
# [86/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.18.38_CAM_1.mp4
#   ℹ️ 총 프레임 수: 571
# ...........
#   -> 571/571 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (39.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.18.38_CAM_1.csv
#
# [87/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.19.28_CAM_1.mp4
#   ℹ️ 총 프레임 수: 595
# ...........
#   -> 595/595 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP082_20221027_14.19.28_CAM_1.csv
#
# [88/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.01.06_CAM_1.mp4
#   ℹ️ 총 프레임 수: 554
# ...........
#   -> 554/554 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (38.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.01.06_CAM_1.csv
#
# [89/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.01.55_CAM_1.mp4
#   ℹ️ 총 프레임 수: 591
# ...........
#   -> 591/591 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.01.55_CAM_1.csv
#
# [90/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.02.45_CAM_1.mp4
#   ℹ️ 총 프레임 수: 619
# ............
#   -> 619/619 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.02.45_CAM_1.csv
#
# [91/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.03.39_CAM_1.mp4
#   ℹ️ 총 프레임 수: 602
# ............
#   -> 602/602 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (41.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.03.39_CAM_1.csv
#
# [92/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.04.44_CAM_1.mp4
#   ℹ️ 총 프레임 수: 607
# ............
#   -> 607/607 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (42.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP093_20221025_14.04.44_CAM_1.csv
#
# [93/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.20.51_CAM_1.mp4
#   ℹ️ 총 프레임 수: 687
# .............
#   -> 687/687 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (48.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.20.51_CAM_1.csv
#
# [94/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.21.48_CAM_1.mp4
#   ℹ️ 총 프레임 수: 671
# .............
#   -> 671/671 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (46.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.21.48_CAM_1.csv
#
# [95/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.22.43_CAM_1.mp4
#   ℹ️ 총 프레임 수: 680
# .............
#   -> 680/680 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (47.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.22.43_CAM_1.csv
#
# [96/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.23.38_CAM_1.mp4
#   ℹ️ 총 프레임 수: 663
# .............
#   -> 663/663 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (45.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.23.38_CAM_1.csv
#
# [97/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.24.32_CAM_1.mp4
#   ℹ️ 총 프레임 수: 666
# .............
#   -> 666/666 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (47.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.24.32_CAM_1.csv
#
# [98/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.25.26_CAM_1.mp4
#   ℹ️ 총 프레임 수: 662
# .............
#   -> 662/662 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (45.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.25.26_CAM_1.csv
#
# [99/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.26.20_CAM_1.mp4
#   ℹ️ 총 프레임 수: 635
# ............
#   -> 635/635 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (44.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.26.20_CAM_1.csv
#
# [100/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.27.16_CAM_1.mp4
#   ℹ️ 총 프레임 수: 720
# ..............
#   -> 720/720 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (49.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP095_20221024_14.27.16_CAM_1.csv
#
# [101/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.52.51_CAM_1.mp4
#   ℹ️ 총 프레임 수: 671
# .............
#   -> 671/671 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (46.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.52.51_CAM_1.csv
#
# [102/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.54.00_CAM_1.mp4
#   ℹ️ 총 프레임 수: 614
# ............
#   -> 614/614 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (44.1초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.54.00_CAM_1.csv
#
# [103/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.54.55_CAM_1.mp4
#   ℹ️ 총 프레임 수: 646
# ............
#   -> 646/646 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (45.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.54.55_CAM_1.csv
#
# [104/116] 분석 시작: 필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.55.52_CAM_1.mp4
#   ℹ️ 총 프레임 수: 1174
# .......................
#   -> 1174/1174 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (82.0초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_A_Mat_Hundred_고급_actorP099_20221028_10.55.52_CAM_1.csv
#
# [105/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.15.09_CAM_1.mp4
#   ℹ️ 총 프레임 수: 667
# .............
#   -> 667/667 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (46.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.15.09_CAM_1.csv
#
# [106/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.16.15_CAM_1.mp4
#   ℹ️ 총 프레임 수: 639
# ............
#   -> 639/639 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (43.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.16.15_CAM_1.csv
#
# [107/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.17.09_CAM_1.mp4
#   ℹ️ 총 프레임 수: 650
# .............
#   -> 650/650 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (45.7초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.17.09_CAM_1.csv
#
# [108/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.18.05_CAM_1.mp4
#   ℹ️ 총 프레임 수: 658
# .............
#   -> 658/658 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (45.5초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_14.18.05_CAM_1.csv
#
# [109/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_15.11.39_CAM_1.mp4
#   ℹ️ 총 프레임 수: 691
# .............
#   -> 691/691 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (48.3초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP079_20221028_15.11.39_CAM_1.csv
#
# [110/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.04.49_CAM_1.mp4
#   ℹ️ 총 프레임 수: 792
# ...............
#   -> 792/792 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (55.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.04.49_CAM_1.csv
#
# [111/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.05.59_CAM_1.mp4
#   ℹ️ 총 프레임 수: 808
# ................
#   -> 808/808 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (57.2초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.05.59_CAM_1.csv
#
# [112/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.07.10_CAM_1.mp4
#   ℹ️ 총 프레임 수: 826
# ................
#   -> 826/826 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (56.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.07.10_CAM_1.csv
#
# [113/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.08.25_CAM_1.mp4
#   ℹ️ 총 프레임 수: 839
# ................
#   -> 839/839 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (57.9초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.08.25_CAM_1.csv
#
# [114/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.10.55_CAM_1.mp4
#   ℹ️ 총 프레임 수: 758
# ...............
#   -> 758/758 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (52.8초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.10.55_CAM_1.csv
#
# [115/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.12.05_CAM_1.mp4
#   ℹ️ 총 프레임 수: 760
# ...............
#   -> 760/760 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (52.6초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.12.05_CAM_1.csv
#
# [116/116] 분석 시작: 필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.13.11_CAM_1.mp4
#   ℹ️ 총 프레임 수: 762
# ...............
#   -> 762/762 프레임에서 사람 감지됨.
#   ...정규화 및 보간 적용 중...
#   ✅ 저장 완료! (53.4초) -> /content/drive/MyDrive/shared_googledrive(Sessac Final Project)/dataset/Hundred/keypoint_Hundred/norm_x/norm_필라테스_가산_C_Mat_Hundred_고급_actorP080_20221024_11.13.11_CAM_1.csv
#
# 🎉 작업 종료!
